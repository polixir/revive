# %%
import numpy as np

# %%
data = dict(np.load("./ib.npz"))

# %%
data["current_next_obs"] = data["next_obs"][...,:6]

# %%
np.savez_compressed("ib_.npz",**data)

# %%
dict(np.load("./ib_.npz"))
# Out:
# {'obs': array([[ 70.      ,  50.      ,  50.      , ...,  50.      ,  21.774622,
#          115.74408 ],
#         [ 70.      ,  50.912544,  40.027885, ...,  50.      ,  21.774622,
#          115.74408 ],
#         [ 70.      ,  51.857235,  30.05473 , ...,  50.      ,  21.774622,
#          115.74408 ],
#         ...,
#         [ 70.      ,  96.547295,   0.      , ...,  46.586044,  48.35257 ,
#          176.43967 ],
#         [ 70.      ,  97.16262 ,   0.      , ...,  45.413273,  48.502865,
#          178.82614 ],
#         [ 70.      ,  97.77095 ,   0.      , ...,  49.251965,  46.99474 ,
#          183.40115 ]], dtype=float32),
#  'next_obs': array([[ 70.      ,  50.912544,  40.027885, ...,  50.      ,  21.774622,
#          115.74408 ],
#         [ 70.      ,  51.857235,  30.05473 , ...,  50.      ,  21.774622,
#          115.74408 ],
#         [ 70.      ,  52.825474,  20.084692, ...,  50.      ,  21.774622,
#          115.74408 ],
#         ...,
# ...
